# %% [markdown]
# # 基本版本
# 卷积和反卷积发现的一个问题就是，zdim为2的时候效果很差
# 现在一个待验证的想法，就是应该是将卷积直接降为2导致效果很差

# %%
import datetime
import os
import time

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from matplotlib import gridspec
from tensorflow import keras


z_dim = 2
batch_size = 128
image_w = 28
image_h = 28
image_d = 1
input_dim = 784
n_epochs = 1000
learning_rate = 0.0002
beta1 = 0.9
results_path = './Results/Adversarial_Autoencoder'

# %%
class Dataset:
    '''
    处理数据，获取迭代器
    '''

    def __init__(self, data):
        self.dataset = tf.data.Dataset.from_tensor_slices(
            (data)).repeat().batch(batch_size).shuffle(buffer_size=128)
        self.iterator = self.dataset.make_initializable_iterator()
        self.next_element = self.iterator.get_next()


class Autoencoder:

    def __init__(self,name="AE"):
        print("初始化自编码器")
        self.encoder_model = self.encoder()
        self.encoder_model.summary()
        self.decoder_model = self.decoder()
        self.decoder_model.summary()
        self.name = name

    def cycle(self, x_input):
        with tf.variable_scope(self.name):
            x_input = tf.reshape(x_input,shape=[-1,image_w,image_h,image_d])
            latent_code = self.encoder_model(x_input)
            self.latent_code = latent_code
            x_output = self.decoder_model(latent_code)
            x_output = tf.reshape(x_output,shape=[-1,image_w,image_h])
            self.variables = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=self.name)
            return x_output

    def predict(self, decoder_input):
        x_output = self.decoder_model(decoder_input)
        return x_output

    def encoder(self):
        with tf.name_scope("encoder"):
            input = keras.layers.Input([image_h,image_w,image_d])
            # x = keras.layers.Conv2D(z_dim//16, kernel_size=(5,5), strides=(2,2), padding='SAME')(input)
            x = keras.layers.Conv2D(16, kernel_size=(2,2), strides=(2,2), padding='SAME')(input) #(14,14)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.LeakyReLU(0.2)(x)
            x = keras.layers.Conv2D(32, kernel_size=(2,2), strides=(2,2), padding='SAME')(x) #(7,7)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.LeakyReLU(0.2)(x)
            x = keras.layers.Conv2D(64, kernel_size=(2,2), strides=(2,2), padding='SAME')(x) # (4,4)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.LeakyReLU(0.2)(x)
            x = keras.layers.Conv2D(z_dim, kernel_size=(2,2), strides=(2,2), padding='SAME')(x) # (2 2 2)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.LeakyReLU(0.2)(x)
            output = keras.layers.GlobalAveragePooling2D()(x) # (2)
            return keras.models.Model(input, output)

    def decoder(self):
        with tf.name_scope("decoder"):
            input = keras.layers.Input([z_dim])
            x = keras.layers.Dense(2*2*z_dim)(input) # 为了化成和(2 2 z_dim)一样的大小，相当于逆GlobalAveragePooling2D
            x = keras.layers.Reshape([2,2,z_dim])(x)
            x = keras.layers.Conv2DTranspose(64, kernel_size=(2,2), strides=(2,2), padding='SAME')(x)#(4,4)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation("relu")(x)
            x = keras.layers.Conv2DTranspose(32, kernel_size=(2,2), strides=(2,2), padding='SAME')(x)#(8,8)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation("relu")(x)
            x = keras.layers.Conv2DTranspose(8, kernel_size=(2,2), strides=(3,3), padding='SAME')(x)#(24,24)
            x = keras.layers.BatchNormalization()(x)
            x = keras.layers.Activation("relu")(x)
            x = keras.layers.Conv2DTranspose(image_d, kernel_size=(5,5), strides=(1,1), padding='VALID')(x)#(28*28*1)
            output = keras.layers.Activation("relu")(x)
            return keras.models.Model(input, output)


class Discriminator:
    def __init__(self):
        print("初始化判别器")
        self.model = self.build()
        self.model.summary()

    def __call__(self,input):
        return self.model(input)

    def build(self):
        input = keras.layers.Input([z_dim])
        fc = keras.layers.Dense(1000,activation="relu")(input)
        fc = keras.layers.Dense(1000,activation="relu")(fc)
        output = keras.layers.Dense(1)(fc)
        return keras.models.Model(input, output)

def form_results():
    """
    Forms folders for each run to store the tensorboard files, saved models and the log files.
    :return: three string pointing to tensorboard, saved models and log paths respectively.
    """
    folder_name = "/{0}_{1}_{2}_{3}_{4}_{5}_Adversarial_Autoencoder". \
        format(time.strftime("%Y-%m-%d %Hh%Mm%Ss", time.localtime()), z_dim,
               learning_rate, batch_size, n_epochs, beta1)
    tensorboard_path = results_path + folder_name + '/Tensorboard'
    saved_model_path = results_path + folder_name + '/Saved_models/'
    log_path = results_path + folder_name + '/log'
    if not os.path.exists(results_path + folder_name):
        os.mkdir(results_path + folder_name)
        os.mkdir(tensorboard_path)
        os.mkdir(saved_model_path)
        os.mkdir(log_path)
    return tensorboard_path, saved_model_path, log_path
    
# Placeholders for input data and the targets
x_input = tf.placeholder(dtype=tf.float32, shape=[batch_size, image_w,image_h], name='Input')
x_target = tf.placeholder(dtype=tf.float32, shape=[
                          batch_size, image_w,image_h], name='Target')
real_distribution = tf.placeholder(
    dtype=tf.float32, shape=[batch_size, z_dim], name='Real_distribution')
decoder_input = tf.placeholder(dtype=tf.float32, shape=[
                               1, z_dim], name='Decoder_input')

def train(train_model):
    fashion_mnist = keras.datasets.fashion_mnist
    (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
    train_images = train_images/255.0
    test_images = test_images/255.0
    train_images_dataset = Dataset(train_images)

    autoencoder = Autoencoder()
    discriminator = Discriminator()
    x_output = autoencoder.cycle(x_input)
    decoder_output = autoencoder.predict(decoder_input)

    input_images = tf.reshape(x_input, [-1, image_h, image_w, 1])
    generated_images = tf.reshape(x_output, [-1, image_h, image_w, 1])
    tf.summary.image(name='Input Images', tensor=input_images, max_outputs=10)
    tf.summary.image(name='Generated Images',tensor=generated_images, max_outputs=10)

    cycle_loss = tf.reduce_mean(tf.square(x_target - x_output))
    d_real = discriminator(real_distribution)
    d_fake = discriminator(autoencoder.latent_code)
    dc_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
        labels=tf.ones_like(d_real), logits=d_real))
    dc_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
        labels=tf.zeros_like(d_fake), logits=d_fake))
    dc_loss = dc_loss_fake + dc_loss_real

    # Generator loss
    generator_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=tf.ones_like(d_fake), logits=d_fake))

    # Optimizers
    autoencoder_optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate,
                                                   beta1=beta1).minimize(cycle_loss)
    discriminator_optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate,
                                                     beta1=beta1).minimize(dc_loss, var_list=discriminator.model.variables)
    generator_optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate,
                                                 beta1=beta1).minimize(generator_loss, var_list=autoencoder.encoder_model.variables)

    init = tf.global_variables_initializer()

    # Tensorboard visualization
    tf.summary.scalar(name='Cycle Loss', tensor=cycle_loss)
    tf.summary.scalar(name='Discriminator Loss', tensor=dc_loss)
    tf.summary.scalar(name='Generator Loss', tensor=generator_loss)
    tf.summary.histogram(name='Encoder Distribution', values=autoencoder.latent_code)
    tf.summary.histogram(name='Real Distribution', values=real_distribution)
    summary_op = tf.summary.merge_all()
    global_step = 0
    # Saving the model
    saver = tf.train.Saver()
    with tf.Session() as sess:
        sess.run(init)
        if train_model:
            sess.run(train_images_dataset.iterator.initializer)
            tensorboard_path, saved_model_path, log_path = form_results()   
            writer = tf.summary.FileWriter(logdir=tensorboard_path)
            for epoch in range(n_epochs):
                n_batches = int(len(train_images) / batch_size)
                for _ in range(n_batches):
                    z_real_dist = np.random.randn(batch_size, z_dim) * 5.
                    batch = sess.run(train_images_dataset.next_element)
                    sess.run(autoencoder_optimizer, feed_dict={x_input: batch, x_target: batch})
                    sess.run(discriminator_optimizer,feed_dict={x_input: batch, x_target: batch, real_distribution: z_real_dist})
                    sess.run(generator_optimizer, feed_dict={x_input: batch, x_target: batch})
                    if _ % 50 == 0:
                        a_loss, d_loss, g_loss, summary = sess.run(
                            [cycle_loss, dc_loss, generator_loss, summary_op],
                            feed_dict={x_input: batch, x_target: batch,
                                       real_distribution: z_real_dist})
                        writer.add_summary(summary, global_step=global_step)
                        print("Epoch: {}, iteration: {}".format(epoch, _))
                        print("Autoencoder Loss: {}".format(a_loss))
                        print("Discriminator Loss: {}".format(d_loss))
                        print("Generator Loss: {}".format(g_loss))
                    global_step += 1
                saver.save(sess, save_path=saved_model_path, global_step=global_step)
        else:
            all_results = os.listdir(results_path)
            all_results.sort()
            print(all_results)
            saver.restore(sess, save_path=tf.train.latest_checkpoint(
                results_path + '/' + all_results[-1] + '/Saved_models/'))

            generate_image_grid(sess, op=decoder_output)

            plt.figure(figsize=(20, 20))
            n_batches = int(len(train_images) / batch_size)
            for i in range(n_batches//10):
                latent_code = sess.run(autoencoder.latent_code, feed_dict={
                    x_input: train_images[batch_size*i:batch_size*(i+1)]})
                plt.scatter(latent_code[:, 0],
                            latent_code[:, 1], c=train_labels[batch_size*i:batch_size*(i+1)])
            plt.colorbar()
            plt.show()

            



def generate_image_grid(sess, op):
    """
    Generates a grid of images by passing a set of numbers to the decoder and getting its output.
    :param sess: Tensorflow Session required to get the decoder output
    :param op: Operation that needs to be called inorder to get the decoder output
    :return: None, displays a matplotlib window with all the merged images.
    """
    plt.figure(figsize=(20, 20))
    n = 10
    x_points = np.linspace(-20, 20, n)
    y_points = np.linspace(-20, 20, n)

    nx, ny = len(x_points), len(y_points)
    plt.subplot()
    gs = gridspec.GridSpec(nx, ny, hspace=0.05, wspace=0.05)

    for i, g in enumerate(gs):
        z = np.concatenate(([x_points[int(i / ny)]], [y_points[int(i % nx)]]))
        z = np.reshape(z, (1, 2))
        x = sess.run(op, feed_dict={decoder_input: z})
        ax = plt.subplot(g)
        img = np.array(x.tolist()).reshape(28, 28)
        ax.imshow(img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_aspect('auto')
    plt.show()

# %%
train(True)
# Out:
# 初始化自编码器
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 16)        80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 14, 14, 16)        64
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 32)          2080
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          8256
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 2)           514
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 2, 2)           8
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 2, 2, 2)           0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2)                 0
# =================================================================
# Total params: 11,386
# Trainable params: 11,158
# Non-trainable params: 228
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 24
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 2)           0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 4, 4, 64)          576
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# activation (Activation)      (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 8, 8, 32)          8224
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# activation_1 (Activation)    (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 24, 24, 8)         1032
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 24, 8)         32
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 8)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         201
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 10,473
# Trainable params: 10,265
# Non-trainable params: 208
# _________________________________________________________________
# 初始化判别器
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              3000
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              1001000
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 1,005,001
# Trainable params: 1,005,001
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Summary name Input Images is illegal; using Input_Images instead.
# INFO:tensorflow:Summary name Generated Images is illegal; using Generated_Images instead.
# INFO:tensorflow:Summary name Cycle Loss is illegal; using Cycle_Loss instead.
# INFO:tensorflow:Summary name Discriminator Loss is illegal; using Discriminator_Loss instead.
# INFO:tensorflow:Summary name Generator Loss is illegal; using Generator_Loss instead.
# INFO:tensorflow:Summary name Encoder Distribution is illegal; using Encoder_Distribution instead.
# INFO:tensorflow:Summary name Real Distribution is illegal; using Real_Distribution instead.
# Epoch: 0, iteration: 0
# Autoencoder Loss: 0.1948791742324829
# Discriminator Loss: 1.1250238418579102
# Generator Loss: 0.6936677694320679
# Epoch: 0, iteration: 50
# Autoencoder Loss: 0.1539427638053894
# Discriminator Loss: 0.5479377508163452
# Generator Loss: 1.2013604640960693
# Epoch: 0, iteration: 100
# Autoencoder Loss: 0.09796701371669769
# Discriminator Loss: 0.28963881731033325
# Generator Loss: 1.9532073736190796
# Epoch: 0, iteration: 150
# Autoencoder Loss: 0.0873601883649826
# Discriminator Loss: 0.20062461495399475
# Generator Loss: 2.173381805419922
# Epoch: 0, iteration: 200
# Autoencoder Loss: 0.09014647454023361
# Discriminator Loss: 0.5260418653488159
# Generator Loss: 2.320502281188965
# Epoch: 0, iteration: 250
# Autoencoder Loss: 0.07940161228179932
# Discriminator Loss: 0.43182188272476196
# Generator Loss: 2.67183780670166
# Epoch: 0, iteration: 300
# Autoencoder Loss: 0.07109037041664124
# Discriminator Loss: 0.5209008455276489
# Generator Loss: 2.85703182220459
# Epoch: 0, iteration: 350
# Autoencoder Loss: 0.07002807408571243
# Discriminator Loss: 0.6270803809165955
# Generator Loss: 2.1571033000946045
# Epoch: 0, iteration: 400
# Autoencoder Loss: 0.06845944374799728
# Discriminator Loss: 0.7439719438552856
# Generator Loss: 2.1018664836883545
# Epoch: 0, iteration: 450
# Autoencoder Loss: 0.06454702466726303
# Discriminator Loss: 0.5150960683822632
# Generator Loss: 1.7235225439071655
# Epoch: 1, iteration: 0
# Autoencoder Loss: 0.06771456450223923
# Discriminator Loss: 0.5212588310241699
# Generator Loss: 1.800994873046875
# Epoch: 1, iteration: 50
# Autoencoder Loss: 0.06388004869222641
# Discriminator Loss: 0.7218718528747559
# Generator Loss: 1.4967232942581177
# Epoch: 1, iteration: 100
# Autoencoder Loss: 0.05930152162909508
# Discriminator Loss: 0.6600050330162048
# Generator Loss: 1.6747691631317139
# Epoch: 1, iteration: 150
# Autoencoder Loss: 0.06077221408486366
# Discriminator Loss: 0.6234990358352661
# Generator Loss: 1.8867173194885254
# Epoch: 1, iteration: 200
# Autoencoder Loss: 0.05781218409538269
# Discriminator Loss: 0.729602575302124
# Generator Loss: 1.4662363529205322
# Epoch: 1, iteration: 250
# Autoencoder Loss: 0.055919427424669266
# Discriminator Loss: 0.650486946105957
# Generator Loss: 1.6965224742889404
# Epoch: 1, iteration: 300
# Autoencoder Loss: 0.055653221905231476
# Discriminator Loss: 0.6797972321510315
# Generator Loss: 1.6492266654968262
# Epoch: 1, iteration: 350
# Autoencoder Loss: 0.059598904103040695
# Discriminator Loss: 0.7975449562072754
# Generator Loss: 1.5024850368499756
# Epoch: 1, iteration: 400
# Autoencoder Loss: 0.06069329380989075
# Discriminator Loss: 0.6902844905853271
# Generator Loss: 1.6614842414855957
# Epoch: 1, iteration: 450
# Autoencoder Loss: 0.05927245318889618
# Discriminator Loss: 0.7298771142959595
# Generator Loss: 1.7420316934585571
# Epoch: 2, iteration: 0
# Autoencoder Loss: 0.05760058015584946
# Discriminator Loss: 0.5777745246887207
# Generator Loss: 1.4400854110717773
# Epoch: 2, iteration: 50
# Autoencoder Loss: 0.055727269500494
# Discriminator Loss: 0.7107056975364685
# Generator Loss: 1.5203280448913574
# Epoch: 2, iteration: 100
# Autoencoder Loss: 0.051236119121313095
# Discriminator Loss: 0.6413768529891968
# Generator Loss: 1.5976412296295166
# Epoch: 2, iteration: 150
# Autoencoder Loss: 0.054317813366651535
# Discriminator Loss: 0.6550018787384033
# Generator Loss: 1.885791540145874
# Epoch: 2, iteration: 200
# Autoencoder Loss: 0.05679931491613388
# Discriminator Loss: 0.646949291229248
# Generator Loss: 1.447121262550354
# Epoch: 2, iteration: 250
# Autoencoder Loss: 0.05155077576637268
# Discriminator Loss: 0.7917113304138184
# Generator Loss: 1.541955590248108
# Epoch: 2, iteration: 300
# Autoencoder Loss: 0.0544118694961071
# Discriminator Loss: 0.6858495473861694
# Generator Loss: 1.5379753112792969
# Epoch: 2, iteration: 350
# Autoencoder Loss: 0.052579812705516815
# Discriminator Loss: 0.7865182161331177
# Generator Loss: 1.595289707183838
# Epoch: 2, iteration: 400
# Autoencoder Loss: 0.049733083695173264
# Discriminator Loss: 0.6576351523399353
# Generator Loss: 1.4662894010543823
# Epoch: 2, iteration: 450
# Autoencoder Loss: 0.04819536209106445
# Discriminator Loss: 0.7306705713272095
# Generator Loss: 1.6853771209716797
# Epoch: 3, iteration: 0
# Autoencoder Loss: 0.054796550422906876
# Discriminator Loss: 0.7058261632919312
# Generator Loss: 1.4328112602233887
# Epoch: 3, iteration: 50
# Autoencoder Loss: 0.049363456666469574
# Discriminator Loss: 0.734971284866333
# Generator Loss: 1.5010432004928589
# Epoch: 3, iteration: 100
# Autoencoder Loss: 0.050465404987335205
# Discriminator Loss: 0.8533955812454224
# Generator Loss: 1.5083942413330078
# Epoch: 3, iteration: 150
# Autoencoder Loss: 0.04738013073801994
# Discriminator Loss: 0.7287482023239136
# Generator Loss: 1.4078245162963867
# Epoch: 3, iteration: 200
# Autoencoder Loss: 0.0463806577026844
# Discriminator Loss: 0.8034483194351196
# Generator Loss: 1.437074065208435
# Epoch: 3, iteration: 250
# Autoencoder Loss: 0.045989133417606354
# Discriminator Loss: 0.7870790958404541
# Generator Loss: 1.2612931728363037
# Epoch: 3, iteration: 300
# Autoencoder Loss: 0.04870888963341713
# Discriminator Loss: 0.7315722703933716
# Generator Loss: 1.5818288326263428
# Epoch: 3, iteration: 350
# Autoencoder Loss: 0.050808217376470566
# Discriminator Loss: 0.7759723663330078
# Generator Loss: 1.2187998294830322
# Epoch: 3, iteration: 400
# Autoencoder Loss: 0.0484754852950573
# Discriminator Loss: 0.9022692441940308
# Generator Loss: 1.4587944746017456
# Epoch: 3, iteration: 450
# Autoencoder Loss: 0.05062583088874817
# Discriminator Loss: 0.7462983727455139
# Generator Loss: 1.5307257175445557
# Epoch: 4, iteration: 0
# Autoencoder Loss: 0.05013350024819374
# Discriminator Loss: 0.8400918841362
# Generator Loss: 1.5147180557250977
# Epoch: 4, iteration: 50
# Autoencoder Loss: 0.04943350702524185
# Discriminator Loss: 0.8922600150108337
# Generator Loss: 1.3899251222610474
# Epoch: 4, iteration: 100
# Autoencoder Loss: 0.051020681858062744
# Discriminator Loss: 0.7572762966156006
# Generator Loss: 1.432190179824829
# Epoch: 4, iteration: 150
# Autoencoder Loss: 0.04594242200255394
# Discriminator Loss: 0.8221933245658875
# Generator Loss: 1.3593801259994507
# Epoch: 4, iteration: 200
# Autoencoder Loss: 0.0465504452586174
# Discriminator Loss: 0.8058202266693115
# Generator Loss: 1.2133846282958984
# Epoch: 4, iteration: 250
# Autoencoder Loss: 0.04719407111406326
# Discriminator Loss: 0.8480750322341919
# Generator Loss: 1.4701869487762451
# Epoch: 4, iteration: 300
# Autoencoder Loss: 0.049163155257701874
# Discriminator Loss: 0.7991422414779663
# Generator Loss: 1.557079792022705
# Epoch: 4, iteration: 350
# Autoencoder Loss: 0.051644496619701385
# Discriminator Loss: 0.8094929456710815
# Generator Loss: 1.3679386377334595
# Epoch: 4, iteration: 400
# Autoencoder Loss: 0.05080557242035866
# Discriminator Loss: 0.9355285167694092
# Generator Loss: 1.2582271099090576
# Epoch: 4, iteration: 450
# Autoencoder Loss: 0.04755118489265442
# Discriminator Loss: 0.883705735206604
# Generator Loss: 1.4772417545318604
# Epoch: 5, iteration: 0
# Autoencoder Loss: 0.0476500540971756
# Discriminator Loss: 0.8842428922653198
# Generator Loss: 1.2041215896606445
# Epoch: 5, iteration: 50
# Autoencoder Loss: 0.04776574298739433
# Discriminator Loss: 0.8164613246917725
# Generator Loss: 1.1880509853363037
# Epoch: 5, iteration: 100
# Autoencoder Loss: 0.04686719551682472
# Discriminator Loss: 0.8875788450241089
# Generator Loss: 1.228356957435608
# Epoch: 5, iteration: 150
# Autoencoder Loss: 0.04672408476471901
# Discriminator Loss: 0.9266976714134216
# Generator Loss: 1.2236500978469849
# Epoch: 5, iteration: 200
# Autoencoder Loss: 0.04449019953608513
# Discriminator Loss: 0.8632016181945801
# Generator Loss: 1.5105352401733398
# Epoch: 5, iteration: 250
# Autoencoder Loss: 0.04076388478279114
# Discriminator Loss: 0.8835859894752502
# Generator Loss: 1.5088484287261963
# Epoch: 5, iteration: 300
# Autoencoder Loss: 0.0479266382753849
# Discriminator Loss: 0.8657860159873962
# Generator Loss: 1.3227977752685547
# Epoch: 5, iteration: 350
# Autoencoder Loss: 0.048456206917762756
# Discriminator Loss: 0.8464406728744507
# Generator Loss: 1.486712098121643
# Epoch: 5, iteration: 400
# Autoencoder Loss: 0.044418029487133026
# Discriminator Loss: 0.8061909079551697
# Generator Loss: 1.1962956190109253
# Epoch: 5, iteration: 450
# Autoencoder Loss: 0.05044180899858475
# Discriminator Loss: 0.8502782583236694
# Generator Loss: 1.1857969760894775
# Epoch: 6, iteration: 0
# Autoencoder Loss: 0.04816150665283203
# Discriminator Loss: 0.9414810538291931
# Generator Loss: 1.4526758193969727
# Epoch: 6, iteration: 50
# Autoencoder Loss: 0.04478467255830765
# Discriminator Loss: 0.9237697720527649
# Generator Loss: 1.3317418098449707
# Epoch: 6, iteration: 100
# Autoencoder Loss: 0.0472392700612545
# Discriminator Loss: 0.8115512132644653
# Generator Loss: 1.3099461793899536
# Epoch: 6, iteration: 150
# Autoencoder Loss: 0.04960893467068672
# Discriminator Loss: 0.9363234639167786
# Generator Loss: 1.1312854290008545
# Epoch: 6, iteration: 200
# Autoencoder Loss: 0.04419592767953873
# Discriminator Loss: 0.9197130799293518
# Generator Loss: 1.1702351570129395
# Epoch: 6, iteration: 250
# Autoencoder Loss: 0.046669118106365204
# Discriminator Loss: 0.9590457081794739
# Generator Loss: 1.4301763772964478
# Epoch: 6, iteration: 300
# Autoencoder Loss: 0.047165822237730026
# Discriminator Loss: 0.7841978073120117
# Generator Loss: 1.682620882987976
# Epoch: 6, iteration: 350
# Autoencoder Loss: 0.046339940279722214
# Discriminator Loss: 0.8760626316070557
# Generator Loss: 1.3475887775421143
# Epoch: 6, iteration: 400
# Autoencoder Loss: 0.04385179281234741
# Discriminator Loss: 0.8989465236663818
# Generator Loss: 1.0938910245895386
# Epoch: 6, iteration: 450
# Autoencoder Loss: 0.046365465968847275
# Discriminator Loss: 0.8849451541900635
# Generator Loss: 1.2306969165802002
# Epoch: 7, iteration: 0
# Autoencoder Loss: 0.04708006978034973
# Discriminator Loss: 0.9005482792854309
# Generator Loss: 1.2830355167388916
# Epoch: 7, iteration: 50
# Autoencoder Loss: 0.04445522278547287
# Discriminator Loss: 0.9327148199081421
# Generator Loss: 1.4368025064468384
# Epoch: 7, iteration: 100
# Autoencoder Loss: 0.043867796659469604
# Discriminator Loss: 0.894855260848999
# Generator Loss: 1.1751527786254883
# Epoch: 7, iteration: 150
# Autoencoder Loss: 0.04461906477808952
# Discriminator Loss: 0.9449338912963867
# Generator Loss: 1.6375794410705566
# Epoch: 7, iteration: 200
# Autoencoder Loss: 0.048290807753801346
# Discriminator Loss: 0.9394488334655762
# Generator Loss: 1.3070122003555298
# Epoch: 7, iteration: 250
# Autoencoder Loss: 0.04219687730073929
# Discriminator Loss: 0.8951563239097595
# Generator Loss: 1.3491368293762207
# Epoch: 7, iteration: 300
# Autoencoder Loss: 0.04640424624085426
# Discriminator Loss: 0.9750716686248779
# Generator Loss: 1.1499320268630981
# Epoch: 7, iteration: 350
# Autoencoder Loss: 0.047872625291347504
# Discriminator Loss: 0.9470382928848267
# Generator Loss: 1.3350378274917603
# Epoch: 7, iteration: 400
# Autoencoder Loss: 0.04438778758049011
# Discriminator Loss: 0.9729407429695129
# Generator Loss: 1.0423719882965088
# Epoch: 7, iteration: 450
# Autoencoder Loss: 0.04394858703017235
# Discriminator Loss: 0.9343677759170532
# Generator Loss: 1.24659264087677
# Epoch: 8, iteration: 0
# Autoencoder Loss: 0.04789712652564049
# Discriminator Loss: 0.9861462712287903
# Generator Loss: 1.1097660064697266
# Epoch: 8, iteration: 50
# Autoencoder Loss: 0.04475821182131767
# Discriminator Loss: 0.8544963598251343
# Generator Loss: 1.313521146774292
# Epoch: 8, iteration: 100
# Autoencoder Loss: 0.047910816967487335
# Discriminator Loss: 0.8827672004699707
# Generator Loss: 1.2994176149368286
# Epoch: 8, iteration: 150
# Autoencoder Loss: 0.045787569135427475
# Discriminator Loss: 0.9240566492080688
# Generator Loss: 1.0596904754638672
# Epoch: 8, iteration: 200
# Autoencoder Loss: 0.04801766574382782
# Discriminator Loss: 0.9475420117378235
# Generator Loss: 1.2127108573913574
# Epoch: 8, iteration: 250
# Autoencoder Loss: 0.04289131611585617
# Discriminator Loss: 0.936151921749115
# Generator Loss: 1.2363159656524658
# Epoch: 8, iteration: 300
# Autoencoder Loss: 0.04639413580298424
# Discriminator Loss: 0.8974144458770752
# Generator Loss: 1.1861250400543213
# Epoch: 8, iteration: 350
# Autoencoder Loss: 0.04527489095926285
# Discriminator Loss: 0.8585125207901001
# Generator Loss: 1.3200500011444092
# Epoch: 8, iteration: 400
# Autoencoder Loss: 0.04765039682388306
# Discriminator Loss: 0.9302332401275635
# Generator Loss: 1.1562376022338867
# Epoch: 8, iteration: 450
# Autoencoder Loss: 0.046333856880664825
# Discriminator Loss: 0.7808967232704163
# Generator Loss: 1.3936123847961426
# Epoch: 9, iteration: 0
# Autoencoder Loss: 0.046408653259277344
# Discriminator Loss: 0.9064942598342896
# Generator Loss: 1.34230637550354
# Epoch: 9, iteration: 50
# Autoencoder Loss: 0.05082506686449051
# Discriminator Loss: 1.0009987354278564
# Generator Loss: 1.2743728160858154
# Epoch: 9, iteration: 100
# Autoencoder Loss: 0.04610791057348251
# Discriminator Loss: 0.9779059886932373
# Generator Loss: 1.1500780582427979
# Epoch: 9, iteration: 150
# Autoencoder Loss: 0.047733813524246216
# Discriminator Loss: 1.022672414779663
# Generator Loss: 1.0938442945480347
# Epoch: 9, iteration: 200
# Autoencoder Loss: 0.04515225440263748
# Discriminator Loss: 0.9422001242637634
# Generator Loss: 1.0391093492507935
# Epoch: 9, iteration: 250
# Autoencoder Loss: 0.049168042838573456
# Discriminator Loss: 0.9623624682426453
# Generator Loss: 1.15482497215271
# Epoch: 9, iteration: 300
# Autoencoder Loss: 0.047243382781744
# Discriminator Loss: 0.9107415676116943
# Generator Loss: 1.2005326747894287
# Epoch: 9, iteration: 350
# Autoencoder Loss: 0.04433215409517288
# Discriminator Loss: 0.948858380317688
# Generator Loss: 1.217474102973938
# Epoch: 9, iteration: 400
# Autoencoder Loss: 0.05057255178689957
# Discriminator Loss: 0.9666593074798584
# Generator Loss: 1.2811250686645508
# Epoch: 9, iteration: 450
# Autoencoder Loss: 0.04439732804894447
# Discriminator Loss: 0.8607432842254639
# Generator Loss: 1.179901123046875
# Epoch: 10, iteration: 0
# Autoencoder Loss: 0.04865330457687378
# Discriminator Loss: 0.9891753196716309
# Generator Loss: 1.2207307815551758
# Epoch: 10, iteration: 50
# Autoencoder Loss: 0.048800256103277206
# Discriminator Loss: 0.8517564535140991
# Generator Loss: 1.1932207345962524
# Epoch: 10, iteration: 100
# Autoencoder Loss: 0.043897248804569244
# Discriminator Loss: 1.0107512474060059
# Generator Loss: 1.1304010152816772
# Epoch: 10, iteration: 150
# Autoencoder Loss: 0.04277852177619934
# Discriminator Loss: 0.9197680950164795
# Generator Loss: 1.267293930053711
# Epoch: 10, iteration: 200
# Autoencoder Loss: 0.04666835442185402
# Discriminator Loss: 0.9217727184295654
# Generator Loss: 1.012657642364502
# Epoch: 10, iteration: 250
# Autoencoder Loss: 0.0423579216003418
# Discriminator Loss: 0.9659485816955566
# Generator Loss: 1.2993861436843872
# Epoch: 10, iteration: 300
# Autoencoder Loss: 0.04627256095409393
# Discriminator Loss: 0.9273357391357422
# Generator Loss: 1.1383635997772217
# Epoch: 10, iteration: 350
# Autoencoder Loss: 0.04848504438996315
# Discriminator Loss: 1.018523931503296
# Generator Loss: 1.1229544878005981
# Epoch: 10, iteration: 400
# Autoencoder Loss: 0.043884772807359695
# Discriminator Loss: 0.9719638824462891
# Generator Loss: 1.390790581703186
# Epoch: 10, iteration: 450
# Autoencoder Loss: 0.04588812217116356
# Discriminator Loss: 1.0505857467651367
# Generator Loss: 0.9888982772827148
# Epoch: 11, iteration: 0
# Autoencoder Loss: 0.04654104262590408
# Discriminator Loss: 0.9867366552352905
# Generator Loss: 1.0308152437210083
# Epoch: 11, iteration: 50
# Autoencoder Loss: 0.04994092509150505
# Discriminator Loss: 1.0188393592834473
# Generator Loss: 0.9595940113067627
# Epoch: 11, iteration: 100
# Autoencoder Loss: 0.04238568991422653
# Discriminator Loss: 0.9088790416717529
# Generator Loss: 1.144694447517395
# Epoch: 11, iteration: 150
# Autoencoder Loss: 0.04973369091749191
# Discriminator Loss: 1.0172163248062134
# Generator Loss: 1.2006125450134277
# Epoch: 11, iteration: 200
# Autoencoder Loss: 0.04424335062503815
# Discriminator Loss: 0.9889776706695557
# Generator Loss: 1.081418752670288
# Epoch: 11, iteration: 250
# Autoencoder Loss: 0.042648810893297195
# Discriminator Loss: 1.024227261543274
# Generator Loss: 1.015343189239502
# Epoch: 11, iteration: 300
# Autoencoder Loss: 0.04459588974714279
# Discriminator Loss: 1.0022387504577637
# Generator Loss: 1.1330270767211914
# Epoch: 11, iteration: 350
# Autoencoder Loss: 0.0450945720076561
# Discriminator Loss: 0.9848540425300598
# Generator Loss: 1.2156563997268677
# Epoch: 11, iteration: 400
# Autoencoder Loss: 0.04519791901111603
# Discriminator Loss: 1.065634846687317
# Generator Loss: 0.8981897234916687
# Epoch: 11, iteration: 450
# Autoencoder Loss: 0.047277361154556274
# Discriminator Loss: 1.0322306156158447
# Generator Loss: 1.1567277908325195
# Epoch: 12, iteration: 0
# Autoencoder Loss: 0.04493756592273712
# Discriminator Loss: 0.990106999874115
# Generator Loss: 1.018454670906067
# Epoch: 12, iteration: 50
# Autoencoder Loss: 0.04638829454779625
# Discriminator Loss: 0.9567033052444458
# Generator Loss: 1.0522541999816895
# Epoch: 12, iteration: 100
# Autoencoder Loss: 0.043265487998723984
# Discriminator Loss: 1.0062570571899414
# Generator Loss: 1.1001622676849365
# Epoch: 12, iteration: 150
# Autoencoder Loss: 0.04513397067785263
# Discriminator Loss: 1.0548206567764282
# Generator Loss: 1.0418331623077393
# Epoch: 12, iteration: 200
# Autoencoder Loss: 0.0496857613325119
# Discriminator Loss: 1.082604169845581
# Generator Loss: 0.925762414932251
# Epoch: 12, iteration: 250
# Autoencoder Loss: 0.0450066439807415
# Discriminator Loss: 1.0615198612213135
# Generator Loss: 1.0489857196807861
# Epoch: 12, iteration: 300
# Autoencoder Loss: 0.046555742621421814
# Discriminator Loss: 1.0679004192352295
# Generator Loss: 1.19148850440979
# Epoch: 12, iteration: 350
# Autoencoder Loss: 0.046165402978658676
# Discriminator Loss: 1.0706350803375244
# Generator Loss: 1.0308492183685303
# Epoch: 12, iteration: 400
# Autoencoder Loss: 0.044896092265844345
# Discriminator Loss: 0.9432921409606934
# Generator Loss: 1.0464684963226318
# Epoch: 12, iteration: 450
# Autoencoder Loss: 0.04567955806851387
# Discriminator Loss: 1.0658814907073975
# Generator Loss: 0.9640997052192688
# Epoch: 13, iteration: 0
# Autoencoder Loss: 0.0497896708548069
# Discriminator Loss: 1.0688881874084473
# Generator Loss: 0.9210122227668762
# Epoch: 13, iteration: 50
# Autoencoder Loss: 0.04411528632044792
# Discriminator Loss: 1.1266052722930908
# Generator Loss: 1.0100566148757935
# Epoch: 13, iteration: 100
# Autoencoder Loss: 0.047435615211725235
# Discriminator Loss: 1.0278420448303223
# Generator Loss: 0.9083646535873413
# Epoch: 13, iteration: 150
# Autoencoder Loss: 0.042384788393974304
# Discriminator Loss: 0.9901556968688965
# Generator Loss: 1.1107062101364136
# Epoch: 13, iteration: 200
# Autoencoder Loss: 0.05071478337049484
# Discriminator Loss: 1.1040632724761963
# Generator Loss: 0.9423330426216125
# Epoch: 13, iteration: 250
# Autoencoder Loss: 0.04623217508196831
# Discriminator Loss: 1.0172470808029175
# Generator Loss: 1.0128811597824097
# Epoch: 13, iteration: 300
# Autoencoder Loss: 0.043684907257556915
# Discriminator Loss: 1.0515849590301514
# Generator Loss: 0.899753212928772
# Epoch: 13, iteration: 350
# Autoencoder Loss: 0.041181329637765884
# Discriminator Loss: 1.1182712316513062
# Generator Loss: 1.0508759021759033
# Epoch: 13, iteration: 400
# Autoencoder Loss: 0.04836665466427803
# Discriminator Loss: 1.0954159498214722
# Generator Loss: 1.021810531616211
# Epoch: 13, iteration: 450
# Autoencoder Loss: 0.04488557577133179
# Discriminator Loss: 1.0878596305847168
# Generator Loss: 0.948123037815094
# Epoch: 14, iteration: 0
# Autoencoder Loss: 0.044477540999650955
# Discriminator Loss: 1.0899425745010376
# Generator Loss: 0.9392272233963013
# Epoch: 14, iteration: 50
# Autoencoder Loss: 0.04681923985481262
# Discriminator Loss: 1.0827587842941284
# Generator Loss: 0.9875428676605225
# Epoch: 14, iteration: 100
# Autoencoder Loss: 0.045074254274368286
# Discriminator Loss: 1.0239673852920532
# Generator Loss: 0.9898399114608765
# Epoch: 14, iteration: 150
# Autoencoder Loss: 0.043884821236133575
# Discriminator Loss: 1.0442553758621216
# Generator Loss: 0.8912381529808044
# Epoch: 14, iteration: 200
# Autoencoder Loss: 0.04440701752901077
# Discriminator Loss: 1.1153762340545654
# Generator Loss: 0.9927319884300232
# Epoch: 14, iteration: 250
# Autoencoder Loss: 0.04536178335547447
# Discriminator Loss: 1.1105717420578003
# Generator Loss: 0.9591202735900879
# Epoch: 14, iteration: 300
# Autoencoder Loss: 0.04339229688048363
# Discriminator Loss: 1.0705385208129883
# Generator Loss: 0.8862552046775818
# Epoch: 14, iteration: 350
# Autoencoder Loss: 0.04518002271652222
# Discriminator Loss: 0.961648166179657
# Generator Loss: 0.9625759720802307
# Epoch: 14, iteration: 400
# Autoencoder Loss: 0.0459190309047699
# Discriminator Loss: 1.1522612571716309
# Generator Loss: 0.9490607380867004
# Epoch: 14, iteration: 450
# Autoencoder Loss: 0.04379309341311455
# Discriminator Loss: 1.063464641571045
# Generator Loss: 1.0160486698150635
# Epoch: 15, iteration: 0
# Autoencoder Loss: 0.04382842406630516
# Discriminator Loss: 1.0912736654281616
# Generator Loss: 0.9490766525268555
# Epoch: 15, iteration: 50
# Autoencoder Loss: 0.046727605164051056
# Discriminator Loss: 1.2109720706939697
# Generator Loss: 0.854975163936615
# Epoch: 15, iteration: 100
# Autoencoder Loss: 0.048342715948820114
# Discriminator Loss: 1.1340818405151367
# Generator Loss: 1.018913984298706
# Epoch: 15, iteration: 150
# Autoencoder Loss: 0.045127931982278824
# Discriminator Loss: 1.117255687713623
# Generator Loss: 0.9508283138275146
# Epoch: 15, iteration: 200
# Autoencoder Loss: 0.046506647020578384
# Discriminator Loss: 1.0861446857452393
# Generator Loss: 0.9429948925971985
# Epoch: 15, iteration: 250
# Autoencoder Loss: 0.047405630350112915
# Discriminator Loss: 1.1131348609924316
# Generator Loss: 0.8158665299415588
# Epoch: 15, iteration: 300
# Autoencoder Loss: 0.04454027861356735
# Discriminator Loss: 1.2452821731567383
# Generator Loss: 0.8382677435874939
# Epoch: 15, iteration: 350
# Autoencoder Loss: 0.04780204966664314
# Discriminator Loss: 1.130760908126831
# Generator Loss: 0.8760582208633423
# Epoch: 15, iteration: 400
# Autoencoder Loss: 0.04518118128180504
# Discriminator Loss: 1.1231393814086914
# Generator Loss: 0.9664572477340698
# Epoch: 15, iteration: 450
# Autoencoder Loss: 0.04659086465835571
# Discriminator Loss: 1.1013838052749634
# Generator Loss: 0.9829342365264893
# Epoch: 16, iteration: 0
# Autoencoder Loss: 0.04281369969248772
# Discriminator Loss: 1.1603248119354248
# Generator Loss: 0.889080822467804
# Epoch: 16, iteration: 50
# Autoencoder Loss: 0.045130934566259384
# Discriminator Loss: 1.0757091045379639
# Generator Loss: 0.9268819093704224
# Epoch: 16, iteration: 100
# Autoencoder Loss: 0.047887373715639114
# Discriminator Loss: 1.2242234945297241
# Generator Loss: 0.8552700877189636
# Epoch: 16, iteration: 150
# Autoencoder Loss: 0.04592786356806755
# Discriminator Loss: 1.130035400390625
# Generator Loss: 0.8256100416183472
# Epoch: 16, iteration: 200
# Autoencoder Loss: 0.04554202780127525
# Discriminator Loss: 1.1108121871948242
# Generator Loss: 0.9428757429122925
# Epoch: 16, iteration: 250
# Autoencoder Loss: 0.04461486637592316
# Discriminator Loss: 1.2006771564483643
# Generator Loss: 0.854455828666687
# Epoch: 16, iteration: 300
# Autoencoder Loss: 0.04469875246286392
# Discriminator Loss: 1.1272203922271729
# Generator Loss: 0.8956594467163086
# Epoch: 16, iteration: 350
# Autoencoder Loss: 0.04491564631462097
# Discriminator Loss: 1.1807762384414673
# Generator Loss: 0.8725299835205078
# Epoch: 16, iteration: 400
# Autoencoder Loss: 0.046286121010780334
# Discriminator Loss: 1.1239194869995117
# Generator Loss: 0.9850282073020935
# Epoch: 16, iteration: 450
# Autoencoder Loss: 0.049229640513658524
# Discriminator Loss: 1.1696665287017822
# Generator Loss: 0.8355432748794556
# Epoch: 17, iteration: 0
# Autoencoder Loss: 0.05092592537403107
# Discriminator Loss: 1.287365198135376
# Generator Loss: 0.860897421836853
# Epoch: 17, iteration: 50
# Autoencoder Loss: 0.045539747923612595
# Discriminator Loss: 1.270899772644043
# Generator Loss: 0.8817623853683472
# Epoch: 17, iteration: 100
# Autoencoder Loss: 0.04792524874210358
# Discriminator Loss: 1.2274351119995117
# Generator Loss: 0.8925855755805969
# Epoch: 17, iteration: 150
# Autoencoder Loss: 0.046312365680933
# Discriminator Loss: 1.1763445138931274
# Generator Loss: 0.8577945232391357
# Epoch: 17, iteration: 200
# Autoencoder Loss: 0.0501040443778038
# Discriminator Loss: 1.2281842231750488
# Generator Loss: 0.8133124113082886
# Epoch: 17, iteration: 250
# Autoencoder Loss: 0.045126646757125854
# Discriminator Loss: 1.22735595703125
# Generator Loss: 0.8829939961433411
# Epoch: 17, iteration: 300
# Autoencoder Loss: 0.04263487458229065
# Discriminator Loss: 1.2464232444763184
# Generator Loss: 0.8162174224853516
# Epoch: 17, iteration: 350
# Autoencoder Loss: 0.04604670777916908
# Discriminator Loss: 1.157820224761963
# Generator Loss: 0.8112655878067017
# Epoch: 17, iteration: 400
# Autoencoder Loss: 0.04391735419631004
# Discriminator Loss: 1.2523958683013916
# Generator Loss: 0.8458546996116638
# Epoch: 17, iteration: 450
# Autoencoder Loss: 0.05058489367365837
# Discriminator Loss: 1.2640974521636963
# Generator Loss: 0.8732354044914246
# Epoch: 18, iteration: 0
# Autoencoder Loss: 0.045221708714962006
# Discriminator Loss: 1.192662000656128
# Generator Loss: 0.7737792730331421
# Epoch: 18, iteration: 50
# Autoencoder Loss: 0.050393786281347275
# Discriminator Loss: 1.2438154220581055
# Generator Loss: 0.8218536376953125
# Epoch: 18, iteration: 100
# Autoencoder Loss: 0.04592109099030495
# Discriminator Loss: 1.246009111404419
# Generator Loss: 0.8245674967765808
# Epoch: 18, iteration: 150
# Autoencoder Loss: 0.04504751041531563
# Discriminator Loss: 1.1945735216140747
# Generator Loss: 0.8547934293746948
# Epoch: 18, iteration: 200
# Autoencoder Loss: 0.04572110250592232
# Discriminator Loss: 1.2306561470031738
# Generator Loss: 0.767456591129303
# Epoch: 18, iteration: 250
# Autoencoder Loss: 0.04944028705358505
# Discriminator Loss: 1.3078110218048096
# Generator Loss: 0.7773630619049072
# Epoch: 18, iteration: 300
# Autoencoder Loss: 0.04318628087639809
# Discriminator Loss: 1.3060102462768555
# Generator Loss: 0.7746679782867432
# Epoch: 20, iteration: 400
# Autoencoder Loss: 0.04340810328722
# Discriminator Loss: 1.3155924081802368
# Generator Loss: 0.7076810598373413
# Epoch: 20, iteration: 450
# Autoencoder Loss: 0.04860175773501396
# Discriminator Loss: 1.3139618635177612
# Generator Loss: 0.7534854412078857
# Epoch: 21, iteration: 0
# Autoencoder Loss: 0.04478197544813156
# Discriminator Loss: 1.3328628540039062
# Generator Loss: 0.7847864627838135
# Epoch: 21, iteration: 50
# Autoencoder Loss: 0.04818173870444298
# Discriminator Loss: 1.3324191570281982
# Generator Loss: 0.7978353500366211
# Epoch: 21, iteration: 100
# Autoencoder Loss: 0.04589734598994255
# Discriminator Loss: 1.3263306617736816
# Generator Loss: 0.776227593421936
# Epoch: 21, iteration: 150
# Autoencoder Loss: 0.04538632556796074
# Discriminator Loss: 1.3765634298324585
# Generator Loss: 0.783919632434845
# Epoch: 21, iteration: 200
# Autoencoder Loss: 0.04828430339694023
# Discriminator Loss: 1.3823752403259277
# Generator Loss: 0.6621281504631042
# Epoch: 21, iteration: 250
# Autoencoder Loss: 0.04237029328942299
# Discriminator Loss: 1.3768281936645508
# Generator Loss: 0.7310478091239929
# Epoch: 21, iteration: 300
# Autoencoder Loss: 0.046840205788612366
# Discriminator Loss: 1.3262921571731567
# Generator Loss: 0.692039966583252
# Epoch: 21, iteration: 350
# Autoencoder Loss: 0.047779638320207596
# Discriminator Loss: 1.3652973175048828
# Generator Loss: 0.7187433838844299
# Epoch: 21, iteration: 400
# Autoencoder Loss: 0.04418330639600754
# Discriminator Loss: 1.3476932048797607
# Generator Loss: 0.770794153213501
# Epoch: 21, iteration: 450
# Autoencoder Loss: 0.04201480373740196
# Discriminator Loss: 1.3420244455337524
# Generator Loss: 0.7961578369140625
# Epoch: 22, iteration: 0
# Autoencoder Loss: 0.04537084326148033
# Discriminator Loss: 1.3368685245513916
# Generator Loss: 0.7029092311859131
# Epoch: 22, iteration: 50
# Autoencoder Loss: 0.04391026124358177
# Discriminator Loss: 1.3155266046524048
# Generator Loss: 0.7665351629257202
# Epoch: 22, iteration: 100
# Autoencoder Loss: 0.04798822104930878
# Discriminator Loss: 1.343934178352356
# Generator Loss: 0.7070515155792236
# Epoch: 22, iteration: 150
# Autoencoder Loss: 0.04267963021993637
# Discriminator Loss: 1.3250339031219482
# Generator Loss: 0.7199733853340149
# Epoch: 22, iteration: 200
# Autoencoder Loss: 0.041543133556842804
# Discriminator Loss: 1.3763209581375122
# Generator Loss: 0.7202877998352051
# Epoch: 22, iteration: 250
# Autoencoder Loss: 0.04775151610374451
# Discriminator Loss: 1.4022289514541626
# Generator Loss: 0.6847479939460754
# Epoch: 22, iteration: 300
# Autoencoder Loss: 0.04658651351928711
# Discriminator Loss: 1.3538577556610107
# Generator Loss: 0.7108699083328247
# Epoch: 22, iteration: 350
# Autoencoder Loss: 0.04636833071708679
# Discriminator Loss: 1.3381190299987793
# Generator Loss: 0.7740181088447571
# Epoch: 22, iteration: 400
# Autoencoder Loss: 0.04233132675290108
# Autoencoder Loss: 0.045759979635477066
# Discriminator Loss: 1.3813139200210571
# Generator Loss: 0.7267464399337769
# Epoch: 25, iteration: 0
# Autoencoder Loss: 0.045289576053619385
# Discriminator Loss: 1.343895435333252
# Generator Loss: 0.7867639660835266
# Epoch: 25, iteration: 50
# Autoencoder Loss: 0.04417228326201439
# Discriminator Loss: 1.3741626739501953
# Generator Loss: 0.6756817102432251
# Epoch: 25, iteration: 100
# Autoencoder Loss: 0.04564234986901283
# Discriminator Loss: 1.350789189338684
# Generator Loss: 0.7796820402145386
# Epoch: 25, iteration: 150
# Autoencoder Loss: 0.0430845245718956
# Discriminator Loss: 1.363433599472046
# Generator Loss: 0.6925002336502075
# Epoch: 25, iteration: 200
# Autoencoder Loss: 0.04616894945502281
# Discriminator Loss: 1.3635609149932861
# Generator Loss: 0.7147035598754883
# Epoch: 25, iteration: 250
# Autoencoder Loss: 0.04852690175175667
# Discriminator Loss: 1.352402687072754
# Generator Loss: 0.706260085105896
# Epoch: 25, iteration: 300
# Autoencoder Loss: 0.044567156583070755
# Discriminator Loss: 1.3595023155212402
# Generator Loss: 0.6744866371154785
# Epoch: 25, iteration: 350
# Autoencoder Loss: 0.045002494007349014
# Discriminator Loss: 1.4096765518188477
# Generator Loss: 0.7037620544433594
# Epoch: 25, iteration: 400
# Autoencoder Loss: 0.04489080607891083
# Discriminator Loss: 1.373140573501587
# Generator Loss: 0.708193302154541
# Epoch: 25, iteration: 450
# Autoencoder Loss: 0.05000850930809975
# Discriminator Loss: 1.3777447938919067
# Generator Loss: 0.7310647964477539
# Epoch: 26, iteration: 0
# Autoencoder Loss: 0.04946994408965111
# Discriminator Loss: 1.3995459079742432
# Generator Loss: 0.6791113615036011
# Epoch: 26, iteration: 50
# Autoencoder Loss: 0.04389554262161255
# Discriminator Loss: 1.3742164373397827
# Generator Loss: 0.7027013301849365
# Epoch: 26, iteration: 100
# Autoencoder Loss: 0.04385536536574364
# Discriminator Loss: 1.3661092519760132
# Generator Loss: 0.6854132413864136
# Epoch: 26, iteration: 150
# Autoencoder Loss: 0.04244661703705788
# Discriminator Loss: 1.363661766052246
# Generator Loss: 0.7252715826034546
# Epoch: 26, iteration: 200
# Autoencoder Loss: 0.044902876019477844
# Discriminator Loss: 1.382542371749878
# Generator Loss: 0.7069258689880371
# Epoch: 26, iteration: 250
# Autoencoder Loss: 0.04203479737043381
# Discriminator Loss: 1.4029724597930908
# Generator Loss: 0.7369934320449829
# Epoch: 26, iteration: 300
# Autoencoder Loss: 0.04855852574110031
# Discriminator Loss: 1.4071309566497803
# Generator Loss: 0.7275111675262451
# Epoch: 26, iteration: 350
# Autoencoder Loss: 0.04555864632129669
# Discriminator Loss: 1.39113450050354
# Generator Loss: 0.7081584930419922
# Epoch: 26, iteration: 400
# Autoencoder Loss: 0.04641936719417572
# Discriminator Loss: 1.3840680122375488
# Generator Loss: 0.7274472117424011
# Epoch: 26, iteration: 450
# Autoencoder Loss: 0.04169411212205887
# Discriminator Loss: 1.364004135131836
# Generator Loss: 0.7132645845413208
# Epoch: 27, iteration: 0
# Discriminator Loss: 1.4221315383911133
# Generator Loss: 0.6639206409454346
# Epoch: 999, iteration: 250
# Autoencoder Loss: 0.036059968173503876
# Discriminator Loss: 1.3920451402664185
# Generator Loss: 0.6988306045532227
# Epoch: 999, iteration: 300
# Autoencoder Loss: 0.039212048053741455
# Discriminator Loss: 1.3838878870010376
# Generator Loss: 0.6948001980781555
# Epoch: 999, iteration: 350
# Autoencoder Loss: 0.04039701074361801
# Discriminator Loss: 1.387718677520752
# Generator Loss: 0.6897053718566895
# Epoch: 999, iteration: 400
# Autoencoder Loss: 0.03781462088227272
# Discriminator Loss: 1.3832318782806396
# Generator Loss: 0.6948460340499878
# Epoch: 999, iteration: 450
# Autoencoder Loss: 0.03782442957162857
# Discriminator Loss: 1.3931045532226562
# Generator Loss: 0.6840810179710388

# %%
train(False)
# Out:
# 初始化自编码器
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 16)        80
# _________________________________________________________________
# batch_normalization (BatchNo (None, 14, 14, 16)        64
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 32)          2080
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          8256
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 2)           514
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 2, 2)           8
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 2, 2, 2)           0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2)                 0
# =================================================================
# Total params: 11,386
# Trainable params: 11,158
# Non-trainable params: 228
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 24
# _________________________________________________________________
# reshape (Reshape)            (None, 2, 2, 2)           0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 4, 4, 64)          576
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# activation (Activation)      (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 8, 8, 32)          8224
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 32)          128
# _________________________________________________________________
# activation_1 (Activation)    (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 24, 24, 8)         1032
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 24, 8)         32
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 8)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         201
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 10,473
# Trainable params: 10,265
# Non-trainable params: 208
# _________________________________________________________________
# 初始化判别器
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              3000
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              1001000
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 1,005,001
# Trainable params: 1,005,001
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Summary name Input Images is illegal; using Input_Images instead.
# INFO:tensorflow:Summary name Generated Images is illegal; using Generated_Images instead.
# INFO:tensorflow:Summary name Cycle Loss is illegal; using Cycle_Loss instead.
# INFO:tensorflow:Summary name Discriminator Loss is illegal; using Discriminator_Loss instead.
# INFO:tensorflow:Summary name Generator Loss is illegal; using Generator_Loss instead.
# INFO:tensorflow:Summary name Encoder Distribution is illegal; using Encoder_Distribution instead.
# INFO:tensorflow:Summary name Real Distribution is illegal; using Real_Distribution instead.
# ['.ipynb_checkpoints', '2018-12-20 11h28m17s_2_0.001_64_100_0.9_Adversarial_Autoencoder', '2018-12-20 12h11m03s_2_0.001_64_50_0.9_Adversarial_Autoencoder', '2018-12-20 13h12m59s_2_0.0002_64_50_0.9_Adversarial_Autoencoder', '2018-12-20 13h19m06s_2_0.0002_64_50_0.9_Adversarial_Autoencoder', '2018-12-20 13h28m07s_2_0.001_64_50_0.9_Adversarial_Autoencoder', '2018-12-20 13h28m36s_2_0.001_64_50_0.9_Adversarial_Autoencoder', '2018-12-20 13h37m39s_2_0.0002_64_200_0.9_Adversarial_Autoencoder', '2018-12-20 13h58m42s_2_0.001_64_1000_0.9_Adversarial_Autoencoder', '2018-12-21 19h06m08s_2_0.001_64_1000_0.9_Adversarial_Autoencoder', '2018-12-21 19h21m59s_2_0.001_128_100_0.9_Adversarial_Autoencoder', '2018-12-21 19h45m13s_2_0.0002_128_1000_0.9_Adversarial_Autoencoder']
# INFO:tensorflow:Restoring parameters from ./Results/Adversarial_Autoencoder/2018-12-21 19h45m13s_2_0.0002_128_1000_0.9_Adversarial_Autoencoder/Saved_models/-468000

# %%
exit()
